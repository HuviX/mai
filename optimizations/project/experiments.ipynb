# %%
from optimizer import batchGD, Nadam
from utils import gen_dataset, plot_
from matplotlib import pyplot as plt
import numpy as np

# %%
N_ITERS = 100000
ETA = 2e-3
BETA1  = 0.975
BETA2 = 0.999
EARLY_STOP = 1e-5 #Оптимизация завершается, если mse меньше этого значения
LR_DECAY_RATE = 0.95
bgd = batchGD(eta=ETA, decay_rate=LR_DECAY_RATE, early_stopping=1e-5)
nadam = Nadam(ETA, BETA1, BETA2, EARLY_STOP)

# %% [markdown]
# # Data_size = 30

# %%
#Сгенерированный набор данных
data_size = 30
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD (BatchSize = 1)

# %%
# %time
w_hat, hist, lr_hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.3 µs
# Полученные параметры [-2.  4.  4.]

# %% [markdown]
# ## Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)
plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# Early Stopping
# Current difference < 1e-05: [2.22044605e-16 8.88178420e-16 0.00000000e+00]
# Полученные параметры [-2.  4.  4.]

# %% [markdown]
# # Data_size = 100

# %%
#Сгенерированный набор данных
data_size = 100
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD

# %%
# %time
w_hat, hist, lr_hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.54 µs
# Early Stopping
# Current difference < 1e-05: [0.0000000e+00 0.0000000e+00 8.8817842e-16]
# Полученные параметры [ 1.99999999  2.         -3.        ]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.58 µs
# Early Stopping
# Current difference < 1e-05: [2.22044605e-16 4.44089210e-16 0.00000000e+00]
# Полученные параметры [ 2.  2. -3.]

# %% [markdown]
# # Data_size = 1000

# %%
#Сгенерированный набор данных
data_size = 1000
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# # BatchGD

# %%
# %time
w_hat, hist, lr_hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 9.78 µs
# Полученные параметры [1.00000071 2.99999999 1.99999994]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# Early Stopping
# Current difference < 1e-05: [2.22044605e-16 8.88178420e-16 0.00000000e+00]
# Полученные параметры [1. 3. 2.]
