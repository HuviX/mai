# %%
from optimizer import batchGD, Nadam
from utils import gen_dataset, plot_
from matplotlib import pyplot as plt

# %%
N_ITERS = 100000
ETA = 2e-3
BETA1  = 0.975
BETA2 = 0.999
EARLY_STOP = 1e-7 #Оптимизация завершается, если mse меньше этого значения
bgd = batchGD(ETA, EARLY_STOP)
nadam = Nadam(ETA, BETA1, BETA2, EARLY_STOP)

# %% [markdown]
# # Data_size = 30

# %%
#Сгенерированный набор данных
data_size = 30
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD (BatchSize = 1)

# %%
# %time
w_hat, hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.44 µs
# Early Stopping
# Current Loss < 1e-07: 9.761706946849004e-08
# Полученные параметры [4.18326348e-04 9.99975454e-01 1.99996876e+00]

# %% [markdown]
# ## Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)
plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.48 µs
# Early Stopping
# Current Loss < 1e-07: 9.971974220631042e-08
# Полученные параметры [8.80281555e-05 9.99711552e-01 1.99992404e+00]

# %% [markdown]
# # Data_size = 100

# %%
#Сгенерированный набор данных
data_size = 100
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD

# %%
# %time
w_hat, hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.29 µs
# Early Stopping
# Current Loss < 1e-07: 9.109901007548696e-08
# Полученные параметры [1.99959654e+00 2.00002683e+00 3.65048558e-05]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# Early Stopping
# Current Loss < 1e-07: 9.914693187492456e-08
# Полученные параметры [ 2.00007119e+00  1.99970407e+00 -7.73049857e-05]

# %% [markdown]
# # Data_size = 1000

# %%
#Сгенерированный набор данных
data_size = 1000
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# # BatchGD

# %%
# %time
w_hat, hist = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# Early Stopping
# Current Loss < 1e-07: 6.603325343566803e-08
# Полученные параметры [ 2.99967176 -4.99998087 -1.99996415]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 4.29 µs
# Early Stopping
# Current Loss < 1e-07: 9.896719520855968e-08
# Полученные параметры [ 2.99995123 -4.99970004 -1.99992255]
