# %%
from optimizer import batchGD, Nadam
from utils import gen_dataset, plot_
from matplotlib import pyplot as plt
import numpy as np
import matplotlib

# %%
N_ITERS = 100000
ETA = 2e-3
BETA1  = 0.975
BETA2 = 0.999
EARLY_STOP = 1e-5 #Оптимизация завершается, если mse меньше этого значения
LR_DECAY_RATE = 0.95
bgd = batchGD(eta=ETA, decay_rate=LR_DECAY_RATE, early_stopping=1e-5)
nadam = Nadam(ETA, BETA1, BETA2, EARLY_STOP)

# %% [markdown]
# # Data_size = 30

# %%
#Сгенерированный набор данных
data_size = 30
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD (BatchSize = 1)

# %%
# %time
w_hat, hist, lr_hist, e = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.25 µs
# Early Stopping
# Current difference < 1e-05: [0.00000000e+00 0.00000000e+00 6.66133815e-16]
# Полученные параметры [ 1. -4.  1.]

# %% [markdown]
# ## Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)
plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# Early Stopping
# Current difference < 1e-05: [2.22973866e-06 9.43442033e-06 2.42379914e-06]
# Полученные параметры [ 0.99940926 -3.99750045  1.00064216]

# %% [markdown]
# # Data_size = 100

# %%
#Сгенерированный набор данных
data_size = 100
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# ## BatchGD

# %%
# %time
w_hat, hist, lr_hist, e = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# Early Stopping
# Current difference < 1e-05: [2.4053388e-17 0.0000000e+00 4.4408921e-16]
# Полученные параметры [1.26087488e-09 4.00000000e+00 3.00000000e+00]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 10 µs
# Early Stopping
# Current difference < 1e-05: [1.95203678e-06 9.46531054e-06 2.46670522e-06]
# Полученные параметры [4.67364081e-04 3.99773377e+00 2.99940941e+00]

# %% [markdown]
# # Data_size = 1000

# %%
#Сгенерированный набор данных
data_size = 1000
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %% [markdown]
# # BatchGD

# %%
# %time
w_hat, hist, lr_hist, e = bgd.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
plt.plot(np.arange(len(lr_hist)), lr_hist, label='lr-history')
plt.title("lr history")
plt.legend()
plt.grid()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# Early Stopping
# Current difference < 1e-05: [8.19544432e-12 4.10782519e-14 0.00000000e+00]
# Полученные параметры [-1.99999997  2.         -3.        ]

# %% [markdown]
# # Nadam

# %%
# %time
w_hat, hist = nadam.do_it(x_train, y_train, N_ITERS)
print("Полученные параметры", w_hat)

plot_(x_train, x_test, y_train, y_test, w_hat, hist)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.3 µs
# Early Stopping
# Current difference < 1e-05: [2.84800322e-06 9.24550500e-06 2.52341038e-06]
# Полученные параметры [-2.00093306  2.00303422 -2.99917198]

# %% [markdown]
# # Parameters comparison

# %%
#Сгенерированный набор данных
data_size = 30
x_train, x_test, y_train, y_test, w = gen_dataset(data_size)


plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();

# %%
best_eta = 2e-3
best_beta1 = 0.975
best_beta2 = 0.999
etas = [0.001, 0.01, 0.05, 0.1, 1]
n_iters = 10000
eta_grid = {}
for i, eta_ in enumerate(etas):
    nadam = Nadam(eta=eta_, beta1=best_beta1, beta2=best_beta2, early_stopping=1e-7)
    _, hist = nadam.do_it(x_train, y_train, n_iters)
    key = (eta_, best_beta1, best_beta2, len(hist))
    eta_grid[key] = hist
    print(f"{i}/{len(etas)}")
# Out:
# 0/5
# Early Stopping
# Current difference < 1e-07: [2.95340776e-08 9.14085341e-08 2.42388267e-08]
# 1/5
# Early Stopping
# Current difference < 1e-07: [2.61223421e-09 6.91631397e-09 4.08097263e-08]
# 2/5
# Early Stopping
# Current difference < 1e-07: [5.45828205e-08 5.64357281e-08 5.40814225e-08]
# 3/5
# 4/5

# %%
fig, ax = plt.subplots(figsize=(20, 10))
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 19}
matplotlib.rc('font', **font)
for k in eta_grid:
    hist = eta_grid[k]
    plt.plot(list(range(len(hist))),hist, label="$ \\alpha = %s$" % (k[0]))
plt.grid()
plt.legend()
plt.rc('legend', fontsize=19)
plt.xlim([0, 1000])
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
betas_1 = np.linspace(0.9, 0.999, 10)
beta1_grid = {}
for i, beta in enumerate(betas_1):
    nadam = Nadam(eta=best_eta, beta1=beta, beta2=best_beta2, early_stopping=1e-7)
    _, hist = nadam.do_it(x_train, y_train, n_iters)
    key = (best_eta, beta, best_beta2, len(hist))
    beta1_grid[key] = hist
    print(f"{i}/{len(betas_1)}")
# Out:
# Early Stopping
# Current difference < 1e-07: [2.69635394e-08 9.26423847e-08 2.42489102e-08]
# 0/10
# Early Stopping
# Current difference < 1e-07: [2.71550837e-08 9.28339217e-08 2.43151104e-08]
# 1/10
# Early Stopping
# Current difference < 1e-07: [2.73372021e-08 9.30193815e-08 2.43787215e-08]
# 2/10
# Early Stopping
# Current difference < 1e-07: [2.73936156e-08 9.28006798e-08 2.43354419e-08]
# 3/10
# Early Stopping
# Current difference < 1e-07: [2.75088337e-08 9.27999191e-08 2.43484115e-08]
# 4/10
# Early Stopping
# Current difference < 1e-07: [2.75908456e-08 9.26967183e-08 2.43337159e-08]
# 5/10
# Early Stopping
# Current difference < 1e-07: [2.76369749e-08 9.24662558e-08 2.42849063e-08]
# 6/10
# Early Stopping
# Current difference < 1e-07: [2.78159911e-08 9.26232078e-08 2.43373275e-08]
# 7/10
# Early Stopping
# Current difference < 1e-07: [2.76370109e-08 9.12830189e-08 2.39959554e-08]
# 8/10
# 9/10

# %%
fig, ax = plt.subplots(figsize=(20, 10))
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 19}
matplotlib.rc('font', **font)
for k in beta1_grid:
    hist = beta1_grid[k]
    plt.plot(list(range(len(hist))),hist, label="$ \\beta_1 = %s$" % (k[1]))
plt.grid()
plt.legend()
plt.rc('legend', fontsize=19)
plt.xlim([0, 1000])
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
betas_2 = np.linspace(0.9, 0.999, 10)
beta2_grid = {}
for i, beta in enumerate(betas_2):
    nadam = Nadam(eta=best_eta, beta1=best_beta1, beta2=beta, early_stopping=1e-7)
    _, hist = nadam.do_it(x_train, y_train, n_iters)
    key = (best_eta, best_beta1, beta, len(hist))
    beta2_grid[key] = hist
    print(f"{i}/{len(betas_2)}")
# Out:
# 0/10
# 1/10
# 2/10
# Early Stopping
# Current difference < 1e-07: [8.04271174e-08 2.38913835e-08 3.28353460e-08]
# 3/10
# Early Stopping
# Current difference < 1e-07: [2.81686341e-09 2.81663248e-09 2.81661405e-09]
# 4/10
# 5/10
# 6/10
# 7/10
# Early Stopping
# Current difference < 1e-07: [1.64143863e-08 1.64143386e-08 1.64143352e-08]
# 8/10
# Early Stopping
# Current difference < 1e-07: [2.76983341e-08 9.23205041e-08 2.42557885e-08]
# 9/10

# %%
fig, ax = plt.subplots(figsize=(20, 10))
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 19}

for k in beta2_grid:
    hist = beta2_grid[k]
    plt.plot(list(range(len(hist))),hist, label="$ \\beta_2 = %s$" % (k[2]))
plt.grid()
plt.legend()
plt.xlim([1000, 2000])
plt.ylim([0, 2])
plt.rc('legend', fontsize=19)
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
w_ = [2, 2, 2]
data_size = 30
x_train, x_test, y_train, y_test, w = gen_dataset(data_size, w_)

plt.plot(x_train, y_train)
plt.title("$f_w(x) = %d + %d*x + %d*x^2$" %(w[0], w[1], w[2]))
plt.grid();
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
w_ = [2, 2, 2]
batch_grid = {}
batches = [10, 30, 50, 100, 1000]
bgd = batchGD(eta=7e-3, decay_rate=LR_DECAY_RATE, early_stopping=1e-5)
for data_size in batches:
    x_train, x_test, y_train, y_test, w = gen_dataset(data_size, w_)
    print(y_train.shape[0])
    _, loss, _, e = bgd.do_it(x_train, y_train, 10000)
    print(e)
    batch_grid[data_size] = loss

fig, ax = plt.subplots(figsize=(20, 10))
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 19}

for k in batch_grid:
    hist = batch_grid[k]
    plt.plot(list(range(len(hist))), hist, label="iterations per epoch = %s" % (k))
plt.grid()
plt.legend()
plt.xlim([0, 1000])
plt.ylim([0, 10])
plt.rc('legend', fontsize=19)
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# 7
# 1429
# 21
# Early Stopping
# Current difference < 1e-05: [0.0000000e+00 4.4408921e-16 8.8817842e-16]
# 408
# 35
# Early Stopping
# Current difference < 1e-05: [2.06501483e-14 2.22044605e-15 0.00000000e+00]
# 240
# 70
# Early Stopping
# Current difference < 1e-05: [8.37108161e-14 4.44089210e-15 0.00000000e+00]
# 111
# 700
# Early Stopping
# Current difference < 1e-05: [5.80691051e-12 2.90878432e-14 0.00000000e+00]
# 10
# Text(0, 0.5, 'loss')

# %%
w_ = [2, 2, 2]
batch_grid = {}
batches = [10, 30, 50, 100, 1000]
bgd = batchGD(eta=2e-3, decay_rate=LR_DECAY_RATE, early_stopping=1e-5)
for data_size in batches:
    x_train, x_test, y_train, y_test, w = gen_dataset(data_size, w_)
    print(y_train.shape[0])
    _, loss, _, e = bgd.do_it(x_train, y_train, 10000)
    print(e)
    batch_grid[data_size] = loss

fig, ax = plt.subplots(figsize=(20, 10))
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 19}

for k in batch_grid:
    hist = batch_grid[k]
    plt.plot(list(range(len(hist))), hist, label="iterations per epoch = %s" % (k))
plt.grid()
plt.legend()
plt.xlim([0, 1000])
plt.ylim([0, 10])
plt.rc('legend', fontsize=19)
plt.xlabel("n iterations")
plt.ylabel("loss")
# Out:
# 7
# 1429
# 21
# 477
# 35
# 286
# 70
# 143
# 700
# 15
# Text(0, 0.5, 'loss')
